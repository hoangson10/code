# %% [markdown]
# <a href="https://colab.research.google.com/github/hoangson10/code/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open ('text.txt',mode='w') as accounts:
  accounts.write('1 vo hoang son 8.0/n')

# %%
with open ('text.txt',mode='w') as accounts:
  print('bmw',file=accounts)

# %%
import pandas as pd
url = '/content/danhsach.csv'
dataframe = pd.read_csv(url)
dataframe.head(2)
# Out:
#    STT      mssv    ten  diem  khoa   he  nam
# 0  1.0  20304050  hoang      4  CKM  CLC   24
# 1  2.0  20304013    tan      5  CKM   DT   12

# %%
import pandas as pd
dataframe = pd.DataFrame()
dataframe['Name'] = ['han','ben']
dataframe['Age'] = [10,21]
dataframe
# Out:
#   Name  Age
# 0  han   10
# 1  ben   21

# %%
import pandas as pd
url = '/content/danhsach.csv'
dataframe = pd.read_csv(url)
dataframe.head(10)
# Out:
#     STT      mssv    ten  diem  khoa   he  nam
# 0   1.0  20304050  hoang      4  CKM  CLC   24
# 1   2.0  20304013    tan      5  CKM   DT   12
# 2   3.0  20304048    han      2  CKM   DT   12
# 3   4.0  20304072    nen      8  CKM  CLC   12
# 4   5.0  20103040    ken      5  CKM   DT   12
# 5   6.0  20405010    men      2  CKM   DT   12
# 6   7.0  20492049    lan      4  CKM  CLC   12
# 7   NaN  20495024    sam      7  CKM  CLC   12
# 8   9.0  20489345    bon      2  CKM  CLC   12
# 9  10.0  23904209    dan      9  CKM   DT   12

# %%
import pandas as pd
url = '/content/danhsach.csv'
dataframe = pd.read_csv(url)
dataframe = dataframe.set_index(dataframe['he'])
dataframe.loc['DT']
# Out:
#      STT      mssv  ten  diem  khoa  he  nam
# he
# DT   2.0  20304013  tan      5  CKM  DT   12
# DT   3.0  20304048  han      2  CKM  DT   12
# DT   5.0  20103040  ken      5  CKM  DT   12
# DT   6.0  20405010  men      2  CKM  DT   12
# DT  10.0  23904209  dan      9  CKM  DT   12

# %%
import pandas as pd
url = '/content/danhsach.csv'
dataframe = pd.read_csv(url)
dataframe = dataframe.set_index(dataframe['he'])
dataframe.loc['DT']
# Out:
#      STT      mssv  ten  diem  khoa  he  nam
# he
# DT   2.0  20304013  tan      5  CKM  DT   12
# DT   3.0  20304048  han      2  CKM  DT   12
# DT   5.0  20103040  ken      5  CKM  DT   12
# DT   6.0  20405010  men      2  CKM  DT   12
# DT  10.0  23904209  dan      9  CKM  DT   12

# %%
import pandas as pd
url = '/content/danhsach.csv'
dataframe = pd.read_csv(url)
dataframe[(dataframe['he'] == 'DT') & (dataframe['khoa'] == 'CKM')]
# Out:
#     STT      mssv  ten  diem  khoa  he  nam
# 1   2.0  20304013  tan      5  CKM  DT   12
# 2   3.0  20304048  han      2  CKM  DT   12
# 4   5.0  20103040  ken      5  CKM  DT   12
# 5   6.0  20405010  men      2  CKM  DT   12
# 9  10.0  23904209  dan      9  CKM  DT   12

# %%
import pandas as pd
url = '/content/danhsach.csv'
dataframe = pd.read_csv(url)
dataframe.drop('he',axis=1).head(10)
# Out:
#     STT      mssv    ten  diem  khoa  nam
# 0   1.0  20304050  hoang      4  CKM   24
# 1   2.0  20304013    tan      5  CKM   12
# 2   3.0  20304048    han      2  CKM   12
# 3   4.0  20304072    nen      8  CKM   12
# 4   5.0  20103040    ken      5  CKM   12
# 5   6.0  20405010    men      2  CKM   12
# 6   7.0  20492049    lan      4  CKM   12
# 7   NaN  20495024    sam      7  CKM   12
# 8   9.0  20489345    bon      2  CKM   12
# 9  10.0  23904209    dan      9  CKM   12

# %%
import pandas as pd
url = '/content/danhsach.csv'
dataframe = pd.read_csv(url)
dataframe.groupby('nam').mean()
# Out:
#      STT          mssv     diem
# nam
# 12   6.0  2.075565e+07  4.888889
# 24   1.0  2.030405e+07  4.000000

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
dataframe = pd.read_csv(url)
dataframe[(dataframe['NOC'] == 'USA') & (dataframe['Medal'] == 'Gold')]
# Out:
#       Year         City      Sport     Discipline  NOC            Event  \
# 47    1924     Chamonix    Skating  Speed skating  USA             500m
# 84    1928   St. Moritz  Bobsleigh      Bobsleigh  USA         five-man
# 86    1928   St. Moritz  Bobsleigh       Skeleton  USA       individual
# 120   1932  Lake Placid  Bobsleigh      Bobsleigh  USA         four-man
# 123   1932  Lake Placid  Bobsleigh      Bobsleigh  USA          two-man
# ...    ...          ...        ...            ...  ...              ...
# 2301  2006        Turin     Skiing  Alpine Skiing  USA  Alpine combined
# 2302  2006        Turin     Skiing  Alpine Skiing  USA     giant slalom
# 2305  2006        Turin     Skiing      Snowboard  USA        Half-pipe
# 2307  2006        Turin     Skiing      Snowboard  USA        Half-pipe
# 2309  2006        Turin     Skiing      Snowboard  USA  Snowboard Cross
#
#      Event gender Medal
# 47              M  Gold
# 84              M  Gold
# 86              M  Gold
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data[(data['NOC'] == 'USA') & (data['Medal'] == 'Gold') & (data['Year']>=1970)]
# Out:
#       Year            City       Sport      Discipline  NOC            Event  \
# 780   1972         Sapporo     Skating   Speed skating  USA            1500m
# 782   1972         Sapporo     Skating   Speed skating  USA             500m
# 784   1972         Sapporo      Skiing   Alpine Skiing  USA           slalom
# 887   1976       Innsbruck     Skating  Figure skating  USA       individual
# 888   1976       Innsbruck     Skating   Speed skating  USA            1000m
# 893   1976       Innsbruck     Skating   Speed skating  USA             500m
# 999   1980     Lake Placid  Ice Hockey      Ice Hockey  USA       ice hockey
# 1002  1980     Lake Placid     Skating   Speed skating  USA           10000m
# 1003  1980     Lake Placid     Skating   Speed skating  USA            1000m
# 1005  1980     Lake Placid     Skating   Speed skating  USA            1500m
# 1007  1980     Lake Placid     Skating   Speed skating  USA            5000m
# ...
